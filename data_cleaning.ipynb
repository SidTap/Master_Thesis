# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = "C://Users//siddd//OneDrive//Desktop//srh//master_Thesis//labeled//Bollywood_labeled.csv"
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to inspect the data
df.head()
# Out:
#    Identifier                                                URL  \
# 0  BlitzIndia  https://blitzindiamedia.com/walls-of-metro-tun...
# 1  BlitzIndia  https://blitzindiamedia.com/india-wyoming-ties...
# 2  BlitzIndia     https://blitzindiamedia.com/third-term-begins/
# 3  BlitzIndia  https://blitzindiamedia.com/how-indian-cinema-...
# 4  BlitzIndia  https://blitzindiamedia.com/pm-modi-inaugurate...
#
#                                         Heading               Date  \
# 0  Walls of Metro tunnels to showcase Bollywood      March 7, 2024
# 1        India-Wyoming ties set to get stronger      June 17, 2024
# 2                             Third term begins      June 10, 2024
# 3           How Indian cinema seduces Hollywood  February 20, 2024
# 4  PM Modi inaugurates BAPS temple in Abu Dhabi  February 15, 2024
#
#                                              Content Economic   Social
# 0  MUMBAI:The Metro Line 2B running from Bandra W...    Right  Liberal
# ...

# %%
df.shape
# Out:
# (1945, 7)

# %%
# Drop rows with any null values
df = df.dropna()
df.head()
# Out:
#    Identifier                                                URL  \
# 0  BlitzIndia  https://blitzindiamedia.com/walls-of-metro-tun...
# 1  BlitzIndia  https://blitzindiamedia.com/india-wyoming-ties...
# 2  BlitzIndia     https://blitzindiamedia.com/third-term-begins/
# 3  BlitzIndia  https://blitzindiamedia.com/how-indian-cinema-...
# 4  BlitzIndia  https://blitzindiamedia.com/pm-modi-inaugurate...
#
#                                         Heading               Date  \
# 0  Walls of Metro tunnels to showcase Bollywood      March 7, 2024
# 1        India-Wyoming ties set to get stronger      June 17, 2024
# 2                             Third term begins      June 10, 2024
# 3           How Indian cinema seduces Hollywood  February 20, 2024
# 4  PM Modi inaugurates BAPS temple in Abu Dhabi  February 15, 2024
#
#                                              Content Economic   Social
# 0  MUMBAI:The Metro Line 2B running from Bandra W...    Right  Liberal
# ...

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    Identifier                                                URL  \
# 0  BlitzIndia  https://blitzindiamedia.com/walls-of-metro-tun...
# 1  BlitzIndia  https://blitzindiamedia.com/india-wyoming-ties...
# 2  BlitzIndia     https://blitzindiamedia.com/third-term-begins/
# 3  BlitzIndia  https://blitzindiamedia.com/how-indian-cinema-...
# 4  BlitzIndia  https://blitzindiamedia.com/pm-modi-inaugurate...
#
#                                         Heading               Date  \
# 0  Walls of Metro tunnels to showcase Bollywood      March 7, 2024
# 1        India-Wyoming ties set to get stronger      June 17, 2024
# 2                             Third term begins      June 10, 2024
# 3           How Indian cinema seduces Hollywood  February 20, 2024
# 4  PM Modi inaugurates BAPS temple in Abu Dhabi  February 15, 2024
#
#                                              Content Economic   Social
# 0  MUMBAI:The Metro Line 2B running from Bandra W...    Right  Liberal
# ...

# %%
print(df.shape)
print(df['Identifier'].unique())
print(df['Economic'].unique())
print(df['Social'].unique())
# Out:
# (1179, 7)
# ['BlitzIndia' 'CNN' 'EconomicTimes' 'FirstPost' 'IndianExpress' 'NDTV'
#  'Swarajya' 'TheNewIndianExpress']
# ['Right' 'Centre' 'Left']
# ['Liberal' 'Centre' 'Authoritarian']

# %%
df.to_csv("C://Users//siddd//OneDrive//Desktop//srh//master_Thesis//cleaning//Bollywood_cleaned.csv", index=False)
